# %% [markdown]
# # Ambizione
#
# Goal is to generate perfect research project title to win Ambizione grant ([link](http://www.snf.ch/en/funding/careers/ambizione/)).
#
# As input we use the successful grantees from the past years ([pdf](http://www.snf.ch/SiteCollectionDocuments/ambizione_liste_beitragsempfangende_e.pdf)).
# This input is converted to a plain text document where each line is the title of a winning proposal.

# %% [markdown]
# Okay, we're in Switzerland, so one issue is that we have mainly English titles in there, but also some German and French ones.
# Since this could impact the quality of our generative model, we try removing the majority of them just by matching common letters non-existing in English.

# %%
bad_words = ['é', 'è', 'à', 'ö', 'ä', 'ü']

with open('ambizione.txt') as oldfile, \
        open('ambizione_cleaned.txt', 'w') as newfile:
    for line in oldfile:
        if not any(bad_word in line for bad_word in bad_words):
            newfile.write(line)

# %% [markdown]
# The titles in this file are sorted alphabetically - maybe this would cause some unwanted patterns during our model's training.
# Let's shuffle the lines to make sure that doesn't happen

# %%
import random
with open('ambizione_cleaned.txt', 'r') as source:
    data = [(random.random(), line) for line in source]
data.sort()
with open('ambizione_cleaned_shuffled.txt', 'w') as target:
    for _, line in data:
        target.write(line)

# %% [markdown]
# Luckily, we don't have to reinvent the wheel to get our model.
# textgenrnn is a Python 3 module on top of Keras/TensorFlow for creating char-rnns, with many cool features - we're gonna use that.

# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# You can specify many options to train the model straight from a text file.
# Let's try to train this with the following ones to start off:
# ```python
# new_model=True,      # this just starts a new model trained from the text
# line_delimited=True, # this tells it that each line starts a new logic
# word_level=True,     # for now use existing words and rearrange them - alternative would be to have each char as a pattern
# max_length=5,        # maximum number of previous patterns to predict next one. Set to 5 as these titles mainly simple compositions of noun + preposition + noun..
# max_gen_length=20,   # maximum patterns considered as generated "sentence".
# num_epochs=3,        # epoch to train for
# gen_epochs=-1,       # after how many epochs a test output is generated, don't want this for now
# train_size=0.8,      # use 80% of the sample for training, rest for validation
# dropout=0.1          # try dropout of 10% of nodes to reduce chance of overtraining
# ```

# %%
textgen.reset()
textgen.train_from_file('ambizione_cleaned_shuffled.txt',
                        new_model=True,
                        line_delimited=True,
                        word_level=True,
                        max_length=5,
                        max_gen_length=20,
                        num_epochs=3,
                        gen_epochs=-1,
                        train_size=0.8,
                        dropout=0.1)
# Out:
# 633 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 6,875 word sequences.
# Epoch 1/3
# 53/53 [==============================] - 16s 309ms/step - loss: 6.9626 - val_loss: 6.7575
# Epoch 2/3
# 53/53 [==============================] - 11s 217ms/step - loss: 6.0333 - val_loss: 7.0451
# Epoch 3/3
# 53/53 [==============================] - 12s 222ms/step - loss: 5.5091 - val_loss: 7.1914

# %% [markdown]
# Huh, the model seems to overtrain on the training data right away. Maybe we don't have sufficient input patterns available?
# Let's still see what it spits out.

# %%
textgen.generate(5, temperature=0.8)
# Out:
#  40%|████      | 2/5 [00:01<00:01,  1.51it/s]
# @ and images atlantic at compared
#
# quantum the and ions of neurodevelopmental from linkage materials
#  80%|████████  | 4/5 [00:01<00:00,  2.39it/s]
# genetic and and social latin the after of : cell in interfaces
#
# . a of , an policy the and : of
# 100%|██████████| 5/5 [00:01<00:00,  3.07it/s]
# phages cloud . idea the communication of the semiconductors

# %% [markdown]
# Hm, that doesn't look great.
#
# The SNF has another funding program available, "Eccellenza", for professorships. They also have a similar sized list of winners.
# If the project titles are good enough to get a better grant, surely we can combine them with our patterns so far.
# The input pdf is [here](http://www.snf.ch/SiteCollectionDocuments/fop_awa_pfs_zusprachen_2018.pdf).
# Same issue with the languages, not with the sorting.

# %%
with open('eccellenza.txt') as oldfile, \
        open('eccellenza_cleaned.txt', 'w') as newfile:
    for line in oldfile:
        if not any(bad_word in line for bad_word in bad_words):
            newfile.write(line)

# %%
filenames = ['ambizione_cleaned_shuffled.txt', 'eccellenza_cleaned.txt']
with open('winning_titles.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
textgen.reset()
textgen.train_from_file('winning_titles.txt',
                        new_model=True,
                        line_delimited=True,
                        word_level=True,
                        max_length=5,
                        max_gen_length=20,
                        num_epochs=3,
                        gen_epochs=-1,
                        train_size=0.8,
                        dropout=0.2)
# Out:
# 1,281 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 13,463 word sequences.
# Epoch 1/3
# 105/105 [==============================] - 36s 346ms/step - loss: 6.9631 - val_loss: 6.8406
# Epoch 2/3
# 105/105 [==============================] - 27s 256ms/step - loss: 6.2167 - val_loss: 7.0172
# Epoch 3/3
# 105/105 [==============================] - 28s 266ms/step - loss: 5.8351 - val_loss: 7.1939

# %% [markdown]
# In fact, I want to have a proposal on "Dark matter", so we can tell the model to start generation with that pattern:

# %%
textgen.generate(5, temperature=0.8, prefix="Dark matter")
# Out:
#  60%|██████    | 3/5 [00:02<00:03,  1.83s/it]
# dark matter the of : idea in in cells s
#
# dark matter and - overlooked
#
# dark matter and of and
#
# dark matter in mechanism metabolic
# 100%|██████████| 5/5 [00:02<00:00,  1.31s/it]
# dark matter , generational macrophages

# %% [markdown]
# Hm, still not great...
#
# Maybe we can work around the issue of the few training patterns?
# There's a thing called transfer learning.
# Basically we take an already trained model, and then fine-tune it on our patterns.
# In this case the idea is to have the existing model being trained on lots of text already know basic things about language patterns.
# The fine-tuning just adds the words specific for this problem.
#
# Our "language" is a bit specific, so let's use something related. The EU publishes their successful grants as well:
# https://data.europa.eu/euodp/en/data/
#
# This is in csv and we need to remove all the overhead and format it so we can feed it to our text generator.

# %%
import pandas as pd
df = pd.read_csv('https://cordis.europa.eu/data/cordis-fp7projects.csv', sep=';',
                 header=0, error_bad_lines=False)

# %%
df
# Out:
#           rcn      id               acronym status            programme  \
# 0      104434  304806         GAUGE/GRAVITY    ONG        FP7-IDEAS-ERC
# 1       98756  265847                  ECO2    ONG      FP7-ENVIRONMENT
# 2      108338  332769             OBESCLAIM    ONG           FP7-PEOPLE
# 3       91155  228344            EUROFLEETS    ONG  FP7-INFRASTRUCTURES
# 4      107499  319818                I2MOVE    ONG        FP7-IDEAS-ERC
# 5       90086  200431             INNOSHADE    ONG              FP7-NMP
# 6      186157  625238                EPIREP    ONG           FP7-PEOPLE
# 7      106470  324514             EPICSTENT    ONG           FP7-PEOPLE
# 8      108144  320330              FLAGSHIP    ONG              FP7-SSH
# 9       97935  256721               STAYERS    ONG              FP7-JTI
# 10     185456  603191              PAINCAGE    ONG           FP7-HEALTH
# 11     185364  321751            CLEARWATER    NaN           FP7-ENERGY
# 12      95633  255578                   MDS    ONG           FP7-PEOPLE
# 13     110517  605036                UMRIDA    ONG        FP7-TRANSPORT
# 14      96221  256695                20PLµS    ONG           FP7-ENERGY
# 15      91823  221059               MESOMED    ONG           FP7-PEOPLE
# 16     104020  300761             MicroPUFA    ONG           FP7-PEOPLE
# 17      86698  201880               FUN OCT    ONG           FP7-HEALTH
# 18     186554  628303             BioPollAr    ONG           FP7-PEOPLE
# 19     110836  613598              MOODFOOD    ONG             FP7-KBBE
# 20     111140  613754                EFFORT    ONG             FP7-KBBE
# 21     109863  609554                  MARE    ONG             FP7-INCO
# 22     203696  115300               EU-AIMS    ONG              FP7-JTI
# 23     203715  115568             AETIONOMY    ONG              FP7-JTI
# 24     110140  602152                PRONIA    ONG           FP7-HEALTH
# 25      92979  238055            BRAINTRAIN    ONG           FP7-PEOPLE
# 26     105236  321868               IO_Q&RM    ONG           FP7-PEOPLE
# 27     109477  603002              MINDVIEW    ONG           FP7-HEALTH
# 28      87805  211605             RURALJOBS    ONG             FP7-KBBE
# 29      88476  212446  KNOWLEDGE2INNOVATION    ONG             FP7-KBBE
# ...       ...     ...                   ...    ...                  ...
# 25748   88634  226653                   GRB    ONG           FP7-PEOPLE
# 25749   87943  208068               SORTING    ONG        FP7-IDEAS-ERC
# 25750   87850  208173                SFEROT    ONG        FP7-IDEAS-ERC
# 25751   87507  221380                 METOP    ONG           FP7-PEOPLE
# 25752   87494  211909            SHARE-PREP    ONG  FP7-INFRASTRUCTURES
# 25753   88015  220447      MASCARENES FERNS    ONG           FP7-PEOPLE
# 25754   88039  220894            NITROFORAM    ONG           FP7-PEOPLE
# 25755   99581  287398      ClimateNight2011    ONG           FP7-PEOPLE
# 25756   88483  221126                BIOLAC    ONG           FP7-PEOPLE
# 25757   89153  230879                 SWEAC    ONG           FP7-PEOPLE
# 25758   87315  224548                Aeolus    CLO              FP7-ICT
# 25759   87629  220942              PHYTOMER    ONG           FP7-PEOPLE
# 25760   87628  220793          INFERENCEHCI    ONG           FP7-PEOPLE
# 25761   87480  208535                 MADEM    ONG        FP7-IDEAS-ERC
# 25762   85315  216026                WOMBAT    CLO              FP7-ICT
# 25763   88043  220959            MITEUKROOT    ONG           FP7-PEOPLE
# 25764   87352  221844        AXON TARGETING    ONG           FP7-PEOPLE
# 25765   87931  225076              SER-MORE    ONG           FP7-PEOPLE
# 25766   87704  220368                  ARBI    ONG           FP7-PEOPLE
# 25767   89855  224909                LEMPEM    ONG           FP7-PEOPLE
# 25768   88684  220596              TOLLICOR    ONG           FP7-PEOPLE
# 25769   87561  210806               4DVIDEO    ONG        FP7-IDEAS-ERC
# 25770   88115  221437  MONOPHOSPHINESC3SYMM    ONG           FP7-PEOPLE
# 25771  105910  314354                METPEX    ONG        FP7-TRANSPORT
# 25772   87923  210896            RNAIEPIMOD    ONG        FP7-IDEAS-ERC
# 25773   87827  224945                  XCIP    ONG           FP7-PEOPLE
# 25774   87650  219376               PTASNCL    ONG           FP7-PEOPLE
# 25775   88041  220941   DEEPOCEANGLACIALCO2    ONG           FP7-PEOPLE
# 25776   99508  287442                 BRAIN    ONG           FP7-PEOPLE
# 25777   99738  287423            LEEDS 2011    ONG           FP7-PEOPLE
#
#                                           topics frameworkProgramme  \
# 0                                     ERC-SG-PE2                FP7
# 1                                   Ocean.2010-3                FP7
# 2                            FP7-PEOPLE-2012-CIG                FP7
# 3                               INFRA-2008-1.1.1                FP7
# 4                                   ERC-2012-SyG                FP7
# 5                                 NMP-2007-1.2-1                FP7
# 6                            FP7-PEOPLE-2013-IIF                FP7
# 7                           FP7-PEOPLE-2012-IAPP                FP7
# 8                                 SSH.2012.7.1-1                FP7
# 9      SP1-JTI-FCH.2009.3.1;SP1-JTI-FCH.2009.3.2                FP7
# 10                           HEALTH.2013.2.2.1-5                FP7
# 11                             ENERGY.2012.2.6.1                FP7
# 12                           FP7-PEOPLE-2009-IEF                FP7
# 13                   AAT.2013.4-2.;AAT.2013.1-1.                FP7
# 14                             ENERGY.2010.2.1-1                FP7
# 15                           PEOPLE-2007-4-2.IIF                FP7
# 16                           FP7-PEOPLE-2011-IEF                FP7
# 17           HEALTH-2007-1.2-1;HEALTH-2007-1.2-2                FP7
# 18                           FP7-PEOPLE-2013-IOF                FP7
# 19                              KBBE.2013.2.1-01                FP7
# 20                              KBBE.2013.1.3-05                FP7
# 21                                 INCO.2013-9.1                FP7
# 22                             IMI-JU-03-2010-05                FP7
# 23                             IMI-JU-08-2012-04                FP7
# 24                           HEALTH.2013.2.2.1-2                FP7
# 25                           FP7-PEOPLE-ITN-2008                FP7
# 26                           FP7-PEOPLE-2012-CIG                FP7
# 27                           HEALTH.2013.2.2.1-2                FP7
# 28                              KBBE-2007-1-4-13                FP7
# 29                              KBBE-2007-1-4-02                FP7
# ...                                          ...                ...
# 25748                        PEOPLE-2007-2-2.ERG                FP7
# 25749                                 ERC-SG-SH1                FP7
# 25750                                 ERC-SG-PE5                FP7
# 25751                        PEOPLE-2007-4-2.IIF                FP7
# 25752                          INFRA-2007-2.2-01                FP7
# 25753                        PEOPLE-2007-2-1.IEF                FP7
# 25754                        PEOPLE-2007-2-1.IEF                FP7
# 25755                      FP7-PEOPLE-2011-NIGHT                FP7
# 25756                        PEOPLE-2007-4-2.IIF                FP7
# 25757                        PEOPLE-2007-2-2.ERG                FP7
# 25758                               ICT-2007.3.7                FP7
# 25759                        PEOPLE-2007-2-1.IEF                FP7
# 25760                        PEOPLE-2007-2-1.IEF                FP7
# 25761                                 ERC-SG-SH1                FP7
# 25762                               ICT-2007.1.4                FP7
# 25763                        PEOPLE-2007-2-1.IEF                FP7
# 25764                        PEOPLE-2007-2-1.IEF                FP7
# 25765                                     PEOPLE                FP7
# 25766                        PEOPLE-2007-2-1.IEF                FP7
# 25767                        PEOPLE-2007-2-2.ERG                FP7
# 25768                        PEOPLE-2007-2-1.IEF                FP7
# 25769                                 ERC-SG-PE5                FP7
# 25770                        PEOPLE-2007-2-1.IEF                FP7
# 25771                            SST.2012.3.1-1.                FP7
# 25772                                 ERC-SG-LS2                FP7
# 25773                        PEOPLE-2007-2-2.ERG                FP7
# 25774                        PEOPLE-2007-2-1.IEF                FP7
# 25775                        PEOPLE-2007-2-1.IEF                FP7
# 25776                      FP7-PEOPLE-2011-NIGHT                FP7
# 25777                      FP7-PEOPLE-2011-NIGHT                FP7
#
#                                                    title   startDate  \
# 0      The Gauge/Gravity Duality and Geometry in Stri...  2013-01-01
# 1      Sub-seabed CO2 Storage: Impact on Marine Ecosy...  2011-05-01
# 2      Fighting against obesity in Europe”: The role ...  2013-09-01
# 3        TOWARDS AN ALLIANCE OF EUROPEAN RESEARCH FLEETS  2009-09-01
# 4      An Intelligent Implantable MOdulator of Vagus ...  2013-04-01
# 5      Innovative Switchable Shading Appliances based...  2008-09-01
# 6      Characterization of epithelial wound repair at...  2015-02-26
# 7      Antibody-functionalised cardiovascular stents ...  2013-04-01
# 8      Forward Looking Analysis of Grand Societal cHa...  2013-01-01
# 9      STAYERS\nStationary PEM fuel cells with lifeti...  2011-01-01
# 10     The NGF system and its interplay with endocann...  2014-04-01
# 11     CommerciaL Energy ARray for Widespread Acceler...  2014-01-01
# 12     The Molecular Basis of Mitochondrial Disease: ...  2010-05-01
# 13     Uncertainty Management for Robust Industrial D...  2013-10-01
# 14     20 percent efficiency on less than 100 µm thic...  2010-10-01
# 15     Marine Environment and Sustainable-fisheries: ...  2009-01-11
# 16     Developing a versatile and efficient microbial...  2012-05-01
# 17               Functional optical coherence tomography  2008-04-01
# 18     Impact of global change on the remobilization ...  2015-06-16
# 19     Multi-country cOllaborative project on the rOl...  2014-01-01
# 20     Ecology from Farm to Fork Of microbial drug Re...  2013-12-01
# 21     Mediterranean Activities for Research and Inno...  2013-09-01
# 22     European Autism Interventions - A Multicentre ...  2012-04-01
# 23     Aetionomy – Organising Mechanistic Knowledge a...  2014-01-01
# 24     Personalised Prognostic Tools for Early Psycho...  2013-10-01
# 25     BrainTrain: Integrative neuroscience school on...  2009-11-01
# 26     Integrated Modeling and Optimization of Qualit...  2012-10-01
# 27          Multimodal Imaging of Neurological Disorders  2013-09-01
# 28     New Sources of Employment to Promote the Wealt...  2008-02-01
# 29     Promoting the exploitation of scientific knowl...  2008-11-01
# ...                                                  ...         ...
# 25748  Probing Star Formation and Galaxy Evolution wi...  2008-10-01
# 25749  The Role of Sorting for Estimation, Market Des...  2008-06-01
# 25750  Secure Function Evaluation – from Theory to Tools  2008-10-01
# 25751                MAC and Network Layers Optimization  2009-03-01
# 25752  Upgrading the Survey of Health, Ageing and Ret...  2008-01-01
# 25753  Investigating the fern diversity of the Mascar...  2008-06-01
# 25754  The New Players in the Marine Nitrogen Cycle: ...  2008-06-01
# 25755                         Climate Night Hamburg 2011  2011-06-01
# 25756  Toward Biodiversity Conservation, Sustainable ...  2008-11-01
# 25757  The Strong, the Weak and the Cunning: Power an...  2008-09-30
# 25758  Distributed Control of Large-Scale Offshore Wi...  2008-05-01
# 25759  FT, a global regulator of plant flowering and ...  2008-08-01
# 25760  Inference and machine learning methods in huma...  2008-07-01
# 25761         Market Design and the Evolution of Markets  2008-09-01
# 25762  Worldwide Observatory of Malicious Behaviors a...  2008-01-01
# 25763  The origin of mitochondria and the root of the...  2009-01-01
# 25764  Anterograde regulation of axon targeting in th...  2008-06-15
# 25765  Development of Serbian Network of Mobility Cen...  2008-09-01
# 25766       Adapting Robot Behavior based on Interaction  2008-08-01
# 25767  Web Graph: Learning Models for Prediction and ...  2008-04-01
# 25768  Dissecting pathogen recognition complexes of T...  2008-08-01
# 25769  4DVideo: 4D spatio-temporal modeling of real-w...  2008-08-01
# 25770  Synthesis of chiral C3-symmetric tricyclic mon...  2008-10-01
# 25771  A MEasurement Tool to determine the quality of...  2012-11-01
# 25772  RNA and Epigenetics: RNAi-Driven Chromatin Mod...  2009-01-01
# 25773  X-Chromosome Inactivation and Plasticity in pr...  2008-03-01
# 25774  Proof-theoretical and Algebraic Study of Noncl...  2008-07-01
# 25775  Using deep-sea corals to test the role of the ...  2008-03-01
# 25776  Be in contact with Research And its Institutio...  2011-04-01
# 25777  "LET’S EXPLORE, DISCOVER AND MAKE FRIENDS WITH...  2011-04-01
#
#           endDate       ...         \
# 0      2018-12-31       ...
# 1      2015-04-30       ...
# 2      2018-08-07       ...
# 3      2013-08-31       ...
# 4      2018-11-30       ...
# 5      2012-08-31       ...
# 6      2017-06-01       ...
# 7      2017-03-31       ...
# 8      2015-12-31       ...
# 9      2014-06-30       ...
# 10     2017-12-31       ...
# 11     2018-12-31       ...
# 12     2012-04-30       ...
# 13     2016-09-30       ...
# 14     2013-09-30       ...
# 15     2010-01-10       ...
# 16     2014-04-30       ...
# 17     2012-09-30       ...
# 18     2018-06-15       ...
# 19     2018-12-31       ...
# 20     2018-11-30       ...
# 21     2016-02-29       ...
# 22     2018-03-31       ...
# 23     2018-12-31       ...
# 24     2018-09-30       ...
# 25     2013-10-31       ...
# 26     2016-09-30       ...
# 27     2018-08-31       ...
# 28     2010-10-31       ...
# 29     2012-01-31       ...
# ...           ...       ...
# 25748  2011-09-30       ...
# 25749  2013-05-31       ...
# 25750  2013-09-30       ...
# 25751  2011-02-28       ...
# 25752  2009-12-31       ...
# 25753  2009-08-31       ...
# 25754  2011-08-31       ...
# 25755  2011-10-31       ...
# 25756  2010-10-31       ...
# 25757  2011-09-29       ...
# 25758  2011-09-30       ...
# 25759  2010-07-31       ...
# 25760  2010-05-31       ...
# 25761  2014-02-28       ...
# 25762  2011-04-30       ...
# 25763  2010-12-31       ...
# 25764  2010-06-14       ...
# 25765  2011-08-31       ...
# 25766  2010-07-31       ...
# 25767  2011-03-31       ...
# 25768  2010-07-31       ...
# 25769  2013-11-30       ...
# 25770  2010-09-30       ...
# 25771  2015-10-31       ...
# 25772  2013-12-31       ...
# 25773  2010-02-28       ...
# 25774  2010-06-30       ...
# 25775  2010-02-28       ...
# 25776  2011-10-31       ...
# 25777  2011-09-30       ...
#
#                                                objective    totalCost  \
# 0      While the three sub-atomic forces are describe...      1253098
# 1      The ECO2 project sets out to assess the risks ...  13978174,12
# 2      The aim of this project is to investigate whet...       100000
# 3      The quality of the infrastructures available f...   8945202,12
# 4      Obesity is one of the greatest public health c...      7175339
# 5      INNOSHADE is concerned with an innovative, nan...   10947605,8
# 6      Inflammatory bowel disease (IBD) affects milli...     230809,8
# 7      An industry-academia collaboration is proposed...   1024185,65
# 8      The objectives of FLAGSHIP are: i) Understandi...    3242723,4
# 9      Economical use of PEM fuel cell power for stat...      4305717
# 10     So far, there are no effective treatments for ...   7878342,13
# 11     Our project consortium will design, build, ins...     22798367
# 12     Mitochondria contain their own DNA (mtDNA), wh...     231427,2
# 13     Virtual prototyping (VP) is a key technology f...   5730351,13
# 14     The overall objective of the current project i...   7018208,98
# 15     Impacts of climate change and human fisheries ...    116865,81
# 16     Polyunstaurated fatty acids are long chain fat...     255069,4
# 17     The aim of FUN OCT is to expand the non-invasi...    7088472,6
# 18     Global change, especially global warming, is a...     244233,3
# 19     MooDFOOD is a Multi-country cOllaborative proj...  11454337,83
# 20     EFFORT studies the complex epidemiology and ec...  11609737,34
# 21     Research & Innovation cooperation between the ...    1174539,2
# 22     Despite dramatic advances in molecular and ima...     36503259
# 23     IMI’s Call 8 is geared to develop knowledge fr...     17546060
# 24     Affective and non-affective psychoses have a m...   9261076,71
# 25     Brain disorders, in particular neurodegenerati...      3316876
# 26     This proposal describes a research plan for in...       100000
# 27     The key concept behind this proposal is the de...    6991289,4
# 28     RuralJobs will quantify the employment needs a...      1400173
# 29     Knowledge2Innovation aims at stimulating and s...      1188515
# ...                                                  ...          ...
# 25748  'This project is aimed at better understanding...        45000
# 25749  Sorting is prevalent in many economic environm...       550000
# 25750  Modern cryptography is known for the introduct...       606000
# 25751  The High Speed Downlink Packet Access (HSDPA) ...    178874,06
# 25752  The Survey of Health, Ageing and Retirement in...    3743601,6
# 25753  The South West Indian Ocean islands are an off...    161364,33
# 25754  Generally, anaerobic respiration of nitrate is...    212823,92
# 25755  Climate Night Hamburg 2011 on September 23, 20...    118195,26
# 25756  A key component of the Millennium Ecosystem As...    154821,03
# 25757  The recent extensions of the European Union br...        45000
# 25758  A key socio-economic challenge for Europe is: ...   3372837,00
# 25759  The floral transition has been an excellent sy...    169390,93
# 25760  My overall vision is that by combining inferen...    161225,98
# 25761  The broad aim of this research program is to u...       840000
# 25762  The WOMBAT project aims at providing new means...   4401578,00
# 25763  'The origins of eukaryotes and mitochondria ar...    161792,99
# 25764  To understand how a functional nervous system ...    168256,91
# 25765  This project aims at streamlining and institut...    218347,22
# 25766  Having robots that are able to understand, com...    161942,68
# 25767  Data intensive systems flourish in the last de...        45000
# 25768  Toll-like receptors (TLRs) are trans-membrane ...    167960,25
# 25769  The focus of this project is the development o...      1757422
# 25770  The primary scientific objectives of this proj...    151369,07
# 25771  Public transport is central to people’s lives ...      3542972
# 25772  RNA interference (RNAi) mediates chromatin mod...       904940
# 25773  In mammals, one of the two X chromosomes is in...        30000
# 25774  Algebraic study of substructural logics is rap...    219494,68
# 25775  The convective circulation of the world's ocea...    168823,92
# 25776  'BRAIN (Be in contact with Research And its In...       295912
# 25777  'The proposed project envisages promotion of s...     14795,49
#
#       ecMaxContribution                          call fundingScheme  \
# 0               1253098         ERC-2012-StG_20111012        ERC-SG
# 1              10500000                FP7-OCEAN-2010         CP-IP
# 2                100000           FP7-PEOPLE-2012-CIG        MC-CIG
# 3               7200000    FP7-INFRASTRUCTURES-2008-1  CP-CSA-Infra
# 4               7175339                  ERC-2012-SyG       ERC-SyG
# 5               7555176          FP7-NMP-2007-LARGE-1         CP-IP
# 6              230809,8           FP7-PEOPLE-2013-IIF        MC-IIF
# 7            1024185,65          FP7-PEOPLE-2012-IAPP       MC-IAPP
# 8               2496656                FP7-SSH-2012-2         CP-FP
# 9               1938497                 FCH-JU-2009-1    JTI-CP-FCH
# 10              5860831  FP7-HEALTH-2013-INNOVATION-1         CP-FP
# 11              7736317             FP7-ENERGY-2012-2            CP
# 12             231427,2           FP7-PEOPLE-2009-IEF        MC-IEF
# 13              3899892            FP7-AAT-2013-RTD-1         CP-FP
# 14              4879986             FP7-ENERGY-2010-1            CP
# 15            116865,81       FP7-PEOPLE-2007-4-2-IIF        MC-IIF
# 16             255069,4           FP7-PEOPLE-2011-IEF        MC-IEF
# 17              5411719             FP7-HEALTH-2007-A         CP-FP
# 18             244233,3           FP7-PEOPLE-2013-IOF        MC-IOF
# 19              8930530  FP7-KBBE-2013-7-single-stage         CP-IP
# 20              8999809  FP7-KBBE-2013-7-single-stage         CP-TP
# 21               990385               FP7-INCO-2013-9        CSA-SA
# 22             20490981                IMI-JU-03-2010    JTI-CP-IMI
# 23              7993234                IMI-JU-08-2012    JTI-CP-IMI
# 24              6000000  FP7-HEALTH-2013-INNOVATION-1         CP-FP
# 25              3316876           FP7-PEOPLE-ITN-2008        MC-ITN
# 26               100000           FP7-PEOPLE-2012-CIG        MC-CIG
# 27              5381872  FP7-HEALTH-2013-INNOVATION-1         CP-FP
# 28              1197104               FP7-KBBE-2007-1         CP-FP
# 29               926229               FP7-KBBE-2007-1        CSA-SA
# ...                 ...                           ...           ...
# 25748             45000           FP7-PEOPLE-ERG-2008        MC-ERG
# 25749            550000                  ERC-2007-StG        ERC-SG
# 25750            606000                  ERC-2007-StG        ERC-SG
# 25751         178874,06       FP7-PEOPLE-2007-4-2-IIF        MC-IIF
# 25752        2499842,08    FP7-INFRASTRUCTURES-2007-1  CP-CSA-Infra
# 25753         161364,33       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25754         212823,92       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25755             80000         FP7-PEOPLE-2011-NIGHT        CSA-SA
# 25756         154821,03       FP7-PEOPLE-2007-4-2-IIF        MC-IIF
# 25757             45000           FP7-PEOPLE-ERG-2008        MC-ERG
# 25758        2500000,00                FP7-ICT-2007-2            CP
# 25759         169390,93       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25760         161225,98       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25761            840000                  ERC-2007-StG        ERC-SG
# 25762        2890795,00                FP7-ICT-2007-1            CP
# 25763         161792,99       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25764         168256,91       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25765            200000             FP7-Adhoc-2007-13        CSA-SA
# 25766         161942,68       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25767             45000       FP7-PEOPLE-2007-2-2-ERG        MC-ERG
# 25768         167960,25       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25769           1757422                  ERC-2007-StG        ERC-SG
# 25770         151369,07       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25771           2699074            FP7-SST-2012-RTD-1         CP-FP
# 25772            904940                  ERC-2007-StG        ERC-SG
# 25773             30000       FP7-PEOPLE-2007-2-2-ERG        MC-ERG
# 25774         219494,68       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25775         168823,92       FP7-PEOPLE-2007-2-1-IEF        MC-IEF
# 25776            105000         FP7-PEOPLE-2011-NIGHT        CSA-SA
# 25777          14795,49         FP7-PEOPLE-2011-NIGHT        CSA-SA
#
#                                              coordinator coordinatorCountry  \
# 0                                  KING'S COLLEGE LONDON                 UK
# 1              HELMHOLTZ ZENTRUM FUR OZEANFORSCHUNG KIEL                 DE
# 2      CENTRO DE INVESTIGACION Y TECNOLOGIA AGROALIME...                 ES
# 3      INSTITUT FRANCAIS DE RECHERCHE POUR L'EXPLOITA...                 FR
# 4      IMPERIAL COLLEGE OF SCIENCE TECHNOLOGY AND MED...                 UK
# 5      FRAUNHOFER GESELLSCHAFT ZUR FOERDERUNG DER ANG...                 DE
# 6                                 KOBENHAVNS UNIVERSITET                 DK
# 7                  NATIONAL UNIVERSITY OF IRELAND GALWAY                 IE
# 8      ISTITUTO DI STUDI PER L'INTEGRAZIONE DEI SISTE...                 IT
# 9                       NEDSTACK FUEL CELL TECHNOLOGY BV                 NL
# 10                              SCUOLA NORMALE SUPERIORE                 IT
# 11                      ATLANTIS OPERATIONS (UK) LIMITED                 UK
# 12                              MEDICAL RESEARCH COUNCIL                 UK
# 13     NUMERICAL MECHANICS APPLICATIONS INTERNATIONAL SA                 BE
# 14                                  UNIVERSITAT KONSTANZ                 DE
# 15     CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                 FR
# 16                               DSM FOOD SPECIALTIES BV                 NL
# 17                         DANMARKS TEKNISKE UNIVERSITET                 DK
# 18     AGENCIA ESTATAL CONSEJO SUPERIOR DEINVESTIGACI...                 ES
# 19                                          STICHTING VU                 NL
# 20                                  UNIVERSITEIT UTRECHT                 NL
# 21     CENTRE FOR RENEWABLE ENERGY SOURCES AND SAVING...                 EL
# 22                               F. HOFFMANN-LA ROCHE AG                 CH
# 23                                    UCB BIOPHARMA SPRL                 BE
# 24              LUDWIG-MAXIMILIANS-UNIVERSITAET MUENCHEN                 DE
# 25                                          STICHTING VU                 NL
# 26                     TECHNISCHE UNIVERSITEIT EINDHOVEN                 NL
# 27     AGENCIA ESTATAL CONSEJO SUPERIOR DEINVESTIGACI...                 ES
# 28                                     DEBRECENI EGYETEM                 HU
# 29                                               INNO AG                 DE
# ...                                                  ...                ...
# 25748                                    HASKOLI ISLANDS                 IS
# 25749                           UNIVERSIDAD POMPEU FABRA                 ES
# 25750                                BAR ILAN UNIVERSITY                 IL
# 25751                         UNIVERSITY OF BEDFORDSHIRE                 UK
# 25752                              UNIVERSITAET MANNHEIM                 DE
# 25753                             NATURAL HISTORY MUSEUM                 UK
# 25754                                 AARHUS UNIVERSITET                 DK
# 25755  ALDEBARAN MARINE RESEARCH & BROADCAST INH FRAN...                 DE
# 25756                       FONDAZIONE ENI ENRICO MATTEI                 IT
# 25757                                     OBUDAI EGYETEM                 HU
# 25758                                AALBORG UNIVERSITET                 DK
# 25759                                  JOHN INNES CENTRE                 UK
# 25760  THE CHANCELLOR MASTERS AND SCHOLARS OF THE UNI...                 UK
# 25761                      UNIVERSITE LIBRE DE BRUXELLES                 BE
# 25762                                          ORANGE SA                 FR
# 25763                  UNIVERSITY OF NEWCASTLE UPON TYNE                 UK
# 25764                           MEDICAL RESEARCH COUNCIL                 UK
# 25765            MASINSKI FAKULTET - UNIVERZITETA U NISU                 RS
# 25766  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                 FR
# 25767  ATHINA-EREVNITIKO KENTRO KAINOTOMIAS STIS TECH...                 EL
# 25768  CEMM - FORSCHUNGSZENTRUM FUER MOLEKULARE MEDIZ...                 AT
# 25769      EIDGENOESSISCHE TECHNISCHE HOCHSCHULE ZUERICH                 CH
# 25770  FUNDACIO PRIVADA INSTITUT CATALA D'INVESTIGACI...                 ES
# 25771                                COVENTRY UNIVERSITY                 UK
# 25772  INSTITUT NATIONAL DE LA SANTE ET DE LA RECHERC...                 FR
# 25773                                   INSTITUT PASTEUR                 FR
# 25774                       TECHNISCHE UNIVERSITAET WIEN                 AT
# 25775                              UNIVERSITY OF BRISTOL                 UK
# 25776                                   Frascati Scienza                 IT
# 25777  Croatian Association for the Promotion and Con...                 HR
#
#                                             participants  \
# 0                                                    NaN
# 1      UNIVERSITETET I TROMSOE - NORGES ARKTISKE UNIV...
# 2                                                    NaN
# 3      HAVFORSKNINGSINSTITUTTET;INSTITUTO ESPANOL DE ...
# 4                                                    NaN
# 5      UNIVERSIDADE DO MINHO;VYZKUMNY USTAV ORGANICKY...
# 6                                                    NaN
# 7      ASHLAND SPECIALTIES IRELAND LIMITED;BALTON SPO...
# 8      STICHTING THE HAGUE INSTITUTE FOR THE INTERNAT...
# 9      SOLVICORE GMBH & CO KG;STIFTELSEN SINTEF;SOLVA...
# 10     MEDIZINISCHE UNIVERSITAET WIEN;AARHUS UNIVERSI...
# 11     HASKONINGDHV NEDERLAND BV;DHI;THE UNIVERSITY O...
# 12                                                   NaN
# 13     INSTITUT NATIONAL DE RECHERCHE ENINFORMATIQUE ...
# 14     PSE AG;PHOTOVOLTECH NV;FRAUNHOFER GESELLSCHAFT...
# 15                                                   NaN
# 16                                                   NaN
# 17     MEDIZINISCHE UNIVERSITAET WIEN;LUDWIG-MAXIMILI...
# 18                                                   NaN
# 19     AARHUS UNIVERSITET;THE UNIVERSITY OF EXETER;GL...
# 20     BUNDESINSTITUT FUER RISIKOBEWERTUNG;PORQ BV;ST...
# 21     CAMARA OFICIAL DE COMERCIO INDUSTRIA Y NAVEGAC...
# 22     Laeknisfraedileg myndgreining ltd;PFIZER LIMIT...
# 23     FUNDACIO BARCELONABETA BRAIN RESEARCH CENTER;U...
# 24     DYNAMIC EVOLUTION GMBH;KLINIKUM DER UNIVERSITA...
# 25     DEUTSCHES ZENTRUM FUR NEURODEGENERATIVE ERKRAN...
# 26                                                   NaN
# 27     BENCAR AB;NORAS MRI PRODUCTS GMBH;GENERAL EQUI...
# 28     INIPA - ISTITUTO NAZIONALE ISTRUZIONE PROFESSI...
# 29     ASSOCIATION DE COORDINATION TECHNIQUE POUR L'I...
# ...                                                  ...
# 25748                                                NaN
# 25749                                                NaN
# 25750                                UNIVERSITY OF HAIFA
# 25751                                                NaN
# 25752  UNIWERSYTET WARSZAWSKI;UNIVERSITEIT ANTWERPEN;...
# 25753                                                NaN
# 25754                                                NaN
# 25755                                                NaN
# 25756                                                NaN
# 25757                         Budapesti Műszaki Főiskola
# 25758  VESTAS WIND SYSTEMS A/S;INDUSTRIAL SYSTEMS AND...
# 25759                                                NaN
# 25760                                                NaN
# 25761                                                NaN
# 25762  NAUKOWA I AKADEMICKA SIEC KOMPUTEROWA - PANSTW...
# 25763                                                NaN
# 25764                                                NaN
# 25765  FAKULTET INFORMACIONIH TEHNOLOGIJA;UNIVERZITET...
# 25766                                                NaN
# 25767                                                NaN
# 25768                                                NaN
# 25769                                                NaN
# 25770                                                NaN
# 25771  F. K. LIOTOPOULOS KAI SIA EE;INSTITUTO TECNOLO...
# 25772                                                NaN
# 25773                                                NaN
# 25774                                                NaN
# 25775                                                NaN
# 25776                                                NaN
# 25777                                                NaN
#
#                                   participantCountries         subjects
# 0                                                  NaN          PSE;SCI
# 1                           NO;UK;NL;BE;PL;DE;IT;FR;SE              ENV
# 2                                                  NaN              LIF
# 3      NO;ES;BG;EL;DE;BE;IE;PT;RO;FR;IT;PL;NL;EE;TR;UK              SCI
# 4                                                  NaN              SCI
# 5                     PT;CZ;DE;FR;IT;SI;NL;TR;IL;ES;CA              NNT
# 6                                                  NaN              LIF
# 7                                             IE;PL;SK              LIF
# 8                        NL;FR;PL;BE;LU;ES;BG;PT;AT;EE              SCI
# 9                                          DE;NO;IT;BE      HFC;SCI;MAT
# 10                                   AT;DK;FR;UK;IT;ES              LIF
# 11                                            NL;DK;UK              SCI
# 12                                                 NaN      SCI;EDU;ITT
# 13                       FR;IT;SE;BE;CH;DE;PL;RU;ES;NL              TRA
# 14                                   DE;BE;IT;CH;AT;UK          ENV;RSE
# 15                                                 NaN          SCI;COO
# 16                                                 NaN              SCI
# 17                                            AT;DE;UK          HCS;MED
# 18                                                 NaN              LIF
# 19                          DK;UK;BE;IT;DE;NL;FR;ES;IS  BIO;ENV;SCI;AGR
# 20                       DE;NL;BE;CH;DK;PL;ES;IT;FR;BG  BIO;ENV;SCI;AGR
# 21                                ES;JO;MA;EL;LB;FR;EG              ITT
# 22                    IS;UK;DE;NL;CH;IT;FR;US;SE;BE;DK              NaN
# 23                       ES;DE;CH;FR;LU;RO;SE;NL;UK;HU              NaN
# 24                                DE;CH;IT;UK;FR;AU;FI              LIF
# 25                             DE;JP;SE;IT;NL;FR;BE;UK          SCI;EDU
# 26                                                 NaN              LIF
# 27                                   SE;DE;ES;FR;IE;IT              LIF
# 28                                IT;RO;FR;ES;UK;BG;LT      EMP;SOC;AGR
# 29                                   FR;ES;UK;HU;EL;IT      ECO;ABI;ITT
# ...                                                ...              ...
# 25748                                              NaN          SCI;EDU
# 25749                                              NaN      ECO;SOC;BUS
# 25750                                               IL      PSE;IPS;TEL
# 25751                                              NaN          SCI;COO
# 25752        PL;BE;IE;CH;AT;IT;FR;DK;CZ;NL;IL;ES;SI;EL              SCI
# 25753                                              NaN          SCI;EDU
# 25754                                              NaN          SCI;EDU
# 25755                                              NaN              SCI
# 25756                                              NaN          SCI;COO
# 25757                                               HU          SCI;EDU
# 25758                                   DK;UK;HR;NL;SE      ELM;IPS;TEL
# 25759                                              NaN          SCI;EDU
# 25760                                              NaN          SCI;EDU
# 25761                                              NaN      ECO;SOC;BUS
# 25762                       PL;AT;IE;SG;EL;NL;ES;IT;FR      ELM;IPS;TEL
# 25763                                              NaN          SCI;EDU
# 25764                                              NaN          SCI;EDU
# 25765                                               RS              EDU
# 25766                                              NaN          SCI;EDU
# 25767                                              NaN          SCI;EDU
# 25768                                              NaN          SCI;EDU
# 25769                                              NaN      PSE;IPS;TEL
# 25770                                              NaN          SCI;EDU
# 25771                 EL;ES;SE;FR;BE;IT;LT;PT;IE;CH;RO              SCI
# 25772                                              NaN          BIO;LIF
# 25773                                              NaN          SCI;EDU
# 25774                                              NaN          SCI;EDU
# 25775                                              NaN          SCI;EDU
# 25776                                              NaN              SCI
# 25777                                              NaN              SCI
#
# [25778 rows x 21 columns]

# %% [markdown]
# We have to be a bit careful now. This table includes related funding where we expect titles to follow similar patterns, but also unrelated ones where this might not be the case. Let's select out the Ambizione equivalent (ERC-SG: Starting Grant for young researchers, and "MC-.." Marie Curie fellows are also young researchers projects).
#
# Okay, we can also drop everything except the title.

# %%
df1 = df[df.fundingScheme == 'ERC-SG']
df2 = df[df['fundingScheme'].str.contains("MC-")]
df = pd.concat([df1, df2])
df = df.filter(['title'])

# %% [markdown]
# Now let's save it to a text file so we can use it.

# %%
df.to_csv('fp7projects.txt', header=None, index=None, sep=' ')

# %%
with open('fp7projects.txt', 'r') as infile, \
        open('fp7projects_cleaned.txt', 'w') as outfile:
    data = infile.read()
    data = data.replace("\"", "")
    outfile.write(data)

# %% [markdown]
# Check that everything is consistent by seeing how many lines of text there are in the file:

# %%
def file_lengthy(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1


print("Number of lines in the file: ", file_lengthy("fp7projects_cleaned.txt"))
# Out:
# Number of lines in the file:  13362

# %% [markdown]
# Okay, a few stray long lines were split in two. We can live with that for now.
#
# Now let's train our model again.This time with 13,362 training patterns - nice!

# %%
textgenbase = textgenrnn(name="base_model")
textgenbase.reset()
textgenbase.train_from_file('fp7projects_cleaned.txt',
                            new_model=True,
                            line_delimited=True,
                            word_level=True,
                            max_length=5,
                            max_gen_length=20,
                            num_epochs=20,
                            gen_epochs=-1,
                            train_size=0.8,
                            dropout=0.2)
# Out:
# 13,361 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 132,169 word sequences.
# Epoch 1/20
# 1032/1032 [==============================] - 420s 407ms/step - loss: 6.3962 - val_loss: 5.9495
# Epoch 2/20
# 1032/1032 [==============================] - 405s 392ms/step - loss: 5.3943 - val_loss: 5.7565
# Epoch 3/20
# 1032/1032 [==============================] - 376s 364ms/step - loss: 4.8322 - val_loss: 5.8203
# Epoch 4/20
# 1032/1032 [==============================] - 375s 363ms/step - loss: 4.3867 - val_loss: 5.8901
# Epoch 5/20
# 1032/1032 [==============================] - 403s 390ms/step - loss: 3.9879 - val_loss: 6.0434
# Epoch 6/20
#    6/1032 [..............................] - ETA: 6:34 - loss: 3.4880

# %% [markdown]
# First save the model weights to a file, and then see how it performs.

# %%
textgenbase.save("base_model.hdf5")
textgenbase.generate(5, max_gen_length=20, temperature=0.5)
# Out:
#  40%|████      | 2/5 [00:00<00:00, 17.75it/s]
# the role of the pathway in integrity of disease
#
# impact of climate change on sea surface microlayer effect
#
# the role of in the regulation of atmospheric carbon dioxide ( - )
#
# novel strategies for brain regeneration
# 100%|██████████| 5/5 [00:00<00:00, 18.07it/s]
# “ biochemical isolation and functional characterization of native - type - iii - v / semiconductor heterostructures on self

# %% [markdown]
# Now that we have our base model, we want to fine-tune it with the patterns from the SNF Ambizione winners. For this we don't start with a new model but build upon the existing one from the previous step. We also don't want to train for many epochs, as this would again lead to overtraining as we've seen before.

# %%
textgenbase.train_from_file('winning_titles.txt',
                            new_model=False,
                            line_delimited=True,
                            word_level=True,
                            max_length=5,
                            max_gen_length=20,
                            num_epochs=3,
                            gen_epochs=-1,
                            train_size=0.8,
                            dropout=0.2)
textgenbase.save("winning_model.hdf5")
# Out:
# 1,281 texts collected.
# Training on 11,857 word sequences.
# Epoch 1/3
# 92/92 [==============================] - 19s 212ms/step - loss: 5.6857 - val_loss: 6.0745
# Epoch 2/3
# 92/92 [==============================] - 19s 206ms/step - loss: 3.3130 - val_loss: 6.3469
# Epoch 3/3
# 92/92 [==============================] - 19s 203ms/step - loss: 2.2932 - val_loss: 6.3899

# %%
textgenbase.generate(5,
                     max_gen_length=18,
                     temperature=0.8)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 18.90it/s]
# infection during the development of progression in children with severe infections
#
# the normative or how regions of atlantic transfer
#
# next generation sustainable organic catalytic compounds
#
# a novel technique for guided treatment of cardiovascular disease
#
# proton transfer in the overcome system

# %% [markdown]
# Here we go. With a temperature of 0.8 there seems to be a reasonable balance between creativity and correctness.
# Temperature here basically defines how "wrong" the model is willing to risk to be on the next prediction.
#
# Who wouldn't fund this research proposal? Maybe I should have submitted something titled:
# ***"dark matter physics with gravitational waves"***
# Just need to work on a model which predicts also the ~15 page project description...
#
# Other outputs:
# 1. *"inference with a focus on machine learning"*
# 2. *"next generation sustainable organic catalytic compounds"*
# 3. *"theoretical foundations of practical impact and global implications"*
# 4. *"theory and applications of linear and topological insulators in matter at interfaces"*
# 5. *"knowledge in the physics of the universe"*
#
# Or we tell it to start with something non-scientific (`prefix='star wars'`):
# 1. *"star wars at the large hadron collider"*
